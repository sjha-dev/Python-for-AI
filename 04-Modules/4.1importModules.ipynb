# %% [markdown]
# ### Importing the modules or packages to access the functions that is most needed and not to need to write 100 lines of code for that function repeatedly just import it before importing check for installation the following packages...

# %%
import math 
number=math.sqrt(25)
print(number)
# Out:
# 5.0

# %%
import numpy as np                                  ## as --> alias
array=np.array([1,2,3,4])
mean_value=np.mean(array)
print(mean_value)
# Out:
# 2.5

# %%
from math import sqrt,pi
print(sqrt(64))
print(pi)
# Out:
# 8.0
# 3.141592653589793

# %%
a=int(input("Enter the value: "))
print(f"the factorial of {a} is ",math.factorial(a))
# Out:
# the factorial of 7 is  5040

# %%
## import our own made modules 

from package.mathematics import mul

print(mul(3,4))
# Out:
# 12

# %%
from package.mathematics import * 
print(mul(3,4))
print(sum(5,4))
print(sub(3,4))
# Out:
# 12
# 9
# -1
