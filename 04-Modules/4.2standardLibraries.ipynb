# %% [markdown]
# ## standard libararies for python are just :
#
# ### OS module provides functions for interacting with the operating system. OS comes under Python's standard utility modules. This module provides a portable way of using operating system-dependent functionality.
#
# ###  Random module: Random module generates random numbers in Python.
# ### datetime module: This module offers classes to efficiently work with dates, times

# %%
import random as rd
a=["harry","Neha","vikas","suresh","sahil","ajay","rishi","himanshu","sumit","pintoo","kumkum","naman","nitin","akanksha"]
print(rd.choice(a))

# %%
import random as rd
a=["harry","Neha","vikas","suresh","sahil","ajay","rishi","himanshu","sumit","pintoo","kumkum","naman","nitin","akanksha"]
print(rd.choice(a))
# Out:
# kumkum

# %%
import random

print(random.randint(1,10))
# Out:
# 8

# %%
## know about your current working directory

import os
cwd=os.getcwd()                    #cwd : current working directory 
print(cwd)
# Out:
# c:\Users\ADMIN\OneDrive\Desktop\python\04-Modules

# %%
## Creating a directory 


# import os 
# mak_dir=os.mkdir("directory name")           mkdir: make directory

# %%
from datetime import date
t = date.today()
print(t)
# Out:
# 2026-05-12
