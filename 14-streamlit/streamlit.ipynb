# %% [markdown]
# ## introduction to streamlit
#
# ### streamlit is an open-source app framework for machine learning and data science projects . it allows to create beautiful web applications for your machine learning and data science projects with simple python scripts.

# %%
## redirect to app.py and widgets.py file
